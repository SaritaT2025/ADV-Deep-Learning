# %% [markdown]
# <a href="https://colab.research.google.com/github/SaritaT2025/ADV-Deep-Learning/blob/main/HW1_AdvAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd homework
# Out:
# [Errno 2] No such file or directory: 'homework'
# /root
